# %%
import gymnasium as gym
import rl_dbs.gym_oscillator
import rl_dbs.gym_oscillator.envs
import rl_dbs.oscillator_cpp
import numpy as np
env = gym.make('oscillator-v0')
env = rl_dbs.gym_oscillator.envs.oscillatorEnv()

# %%
env.reset()
for i in range(1000):
    action = env.action_space.sample()
    state, reward, _, done, _ = env.step(action)
    if done:
        break

# %%
from stable_baselines3 import PPO
policy_kwargs = dict(net_arch=[64])
model = PPO("MlpPolicy", env, verbose = 1,  learning_rate = 0.002, n_steps=128, batch_size = 4, n_epochs=4, clip_range = 0.2, gamma = 0.95, vf_coef =1, ent_coef = 0.005, policy_kwargs = policy_kwargs )
env.seed = 42
env.reset()
model.learn(total_timesteps=10000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------
# | time/              |     |
# |    fps             | 463 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 128 |
# ----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 301        |
# |    iterations           | 2          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 256        |
# | train/                  |            |
# |    approx_kl            | 0.03338286 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | -0.0208    |
# |    learning_rate        | 0.002      |
# |    loss                 | 77.9       |
# |    n_updates            | 4          |
# |    policy_gradient_loss | 0.00578    |
# |    std                  | 0.954      |
# |    value_loss           | 460        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 384         |
# | train/                  |             |
# |    approx_kl            | 0.015914457 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 1.81e-05    |
# |    learning_rate        | 0.002       |
# |    loss                 | 103         |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00679    |
# |    std                  | 0.934       |
# |    value_loss           | 395         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 4           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 512         |
# | train/                  |             |
# |    approx_kl            | 0.050049774 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 26.1        |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.0096     |
# |    std                  | 0.933       |
# |    value_loss           | 328         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 640         |
# | train/                  |             |
# |    approx_kl            | 0.079981476 |
# |    clip_fraction        | 0.395       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.002       |
# |    loss                 | 100         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | 0.0435      |
# |    std                  | 0.98        |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 6           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.017079398 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 32.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.0561      |
# |    std                  | 0.985       |
# |    value_loss           | 65.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 896         |
# | train/                  |             |
# |    approx_kl            | 0.081838086 |
# |    clip_fraction        | 0.393       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 48.9        |
# |    n_updates            | 24          |
# |    policy_gradient_loss | 0.039       |
# |    std                  | 0.999       |
# |    value_loss           | 67.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 8           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.045756765 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.002       |
# |    loss                 | 188         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | 0.0147      |
# |    std                  | 0.957       |
# |    value_loss           | 98.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 9           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1152        |
# | train/                  |             |
# |    approx_kl            | 0.012233297 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 5.36e-07    |
# |    learning_rate        | 0.002       |
# |    loss                 | 32.4        |
# |    n_updates            | 32          |
# |    policy_gradient_loss | 0.0142      |
# |    std                  | 1.03        |
# |    value_loss           | 62.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 10          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.005913929 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.002       |
# |    loss                 | 76.4        |
# |    n_updates            | 36          |
# |    policy_gradient_loss | 0.0214      |
# |    std                  | 0.993       |
# |    value_loss           | 46.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 11          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1408        |
# | train/                  |             |
# |    approx_kl            | 0.020019611 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 1.13e-06    |
# |    learning_rate        | 0.002       |
# |    loss                 | 13.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.0219      |
# |    std                  | 1           |
# |    value_loss           | 44.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 288        |
# |    iterations           | 12         |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 1536       |
# | train/                  |            |
# |    approx_kl            | 0.01002601 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | -3.22e-06  |
# |    learning_rate        | 0.002      |
# |    loss                 | 81.1       |
# |    n_updates            | 44         |
# |    policy_gradient_loss | 0.0215     |
# |    std                  | 0.975      |
# |    value_loss           | 90.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 13          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 1664        |
# | train/                  |             |
# |    approx_kl            | 0.031962067 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.0997      |
# |    learning_rate        | 0.002       |
# |    loss                 | 10.9        |
# |    n_updates            | 48          |
# |    policy_gradient_loss | 0.00509     |
# |    std                  | 0.961       |
# |    value_loss           | 85          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 14          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.021207903 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0342      |
# |    learning_rate        | 0.002       |
# |    loss                 | 10.6        |
# |    n_updates            | 52          |
# |    policy_gradient_loss | 0.0093      |
# |    std                  | 0.942       |
# |    value_loss           | 64.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 289          |
# |    iterations           | 15           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 1920         |
# | train/                  |              |
# |    approx_kl            | 0.0018724264 |
# |    clip_fraction        | 0.156        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.0917       |
# |    learning_rate        | 0.002        |
# |    loss                 | 117          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.0168      |
# |    std                  | 0.916        |
# |    value_loss           | 87.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 16          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.075558096 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.543      |
# |    learning_rate        | 0.002       |
# |    loss                 | 11          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00221     |
# |    std                  | 0.922       |
# |    value_loss           | 32.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 17          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 2176        |
# | train/                  |             |
# |    approx_kl            | 0.018621437 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.465      |
# |    learning_rate        | 0.002       |
# |    loss                 | 146         |
# |    n_updates            | 64          |
# |    policy_gradient_loss | 0.0184      |
# |    std                  | 0.934       |
# |    value_loss           | 211         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 290        |
# |    iterations           | 18         |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 2304       |
# | train/                  |            |
# |    approx_kl            | 0.00894707 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.342      |
# |    learning_rate        | 0.002      |
# |    loss                 | 42.5       |
# |    n_updates            | 68         |
# |    policy_gradient_loss | 0.000865   |
# |    std                  | 0.927      |
# |    value_loss           | 70.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 19          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 2432        |
# | train/                  |             |
# |    approx_kl            | 0.016724199 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.002       |
# |    loss                 | 1.38        |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.00545    |
# |    std                  | 0.924       |
# |    value_loss           | 72.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 290        |
# |    iterations           | 20         |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 2560       |
# | train/                  |            |
# |    approx_kl            | 0.01933092 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | -0.0904    |
# |    learning_rate        | 0.002      |
# |    loss                 | 40.1       |
# |    n_updates            | 76         |
# |    policy_gradient_loss | 0.00885    |
# |    std                  | 0.925      |
# |    value_loss           | 134        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 290        |
# |    iterations           | 21         |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 2688       |
# | train/                  |            |
# |    approx_kl            | 0.01839102 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | -2.71      |
# |    learning_rate        | 0.002      |
# |    loss                 | 9.37       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00373   |
# |    std                  | 0.922      |
# |    value_loss           | 118        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 22          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.056911074 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -19.3       |
# |    learning_rate        | 0.002       |
# |    loss                 | 8.39        |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00259    |
# |    std                  | 0.917       |
# |    value_loss           | 68.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 23           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 2944         |
# | train/                  |              |
# |    approx_kl            | 0.0077409996 |
# |    clip_fraction        | 0.156        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.305       |
# |    learning_rate        | 0.002        |
# |    loss                 | 3.93         |
# |    n_updates            | 88           |
# |    policy_gradient_loss | 0.00832      |
# |    std                  | 0.914        |
# |    value_loss           | 24.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 24          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.025737094 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.468      |
# |    learning_rate        | 0.002       |
# |    loss                 | 17.8        |
# |    n_updates            | 92          |
# |    policy_gradient_loss | 0.00292     |
# |    std                  | 0.914       |
# |    value_loss           | 198         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 25          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.044491574 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.0422      |
# |    learning_rate        | 0.002       |
# |    loss                 | 9.69        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | 0.0107      |
# |    std                  | 0.94        |
# |    value_loss           | 14          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 26           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 0.0051939706 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.002        |
# |    loss                 | 5.45         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.00402      |
# |    std                  | 0.929        |
# |    value_loss           | 17.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 27          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 3456        |
# | train/                  |             |
# |    approx_kl            | 0.010285029 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -13.7       |
# |    learning_rate        | 0.002       |
# |    loss                 | 0.899       |
# |    n_updates            | 104         |
# |    policy_gradient_loss | 0.00226     |
# |    std                  | 0.923       |
# |    value_loss           | 413         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 291        |
# |    iterations           | 28         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 3584       |
# | train/                  |            |
# |    approx_kl            | 0.04033906 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.904      |
# |    learning_rate        | 0.002      |
# |    loss                 | 15.2       |
# |    n_updates            | 108        |
# |    policy_gradient_loss | -0.00368   |
# |    std                  | 0.923      |
# |    value_loss           | 17.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 29          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 3712        |
# | train/                  |             |
# |    approx_kl            | 0.005850941 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -1.34       |
# |    learning_rate        | 0.002       |
# |    loss                 | 4.47        |
# |    n_updates            | 112         |
# |    policy_gradient_loss | 0.0057      |
# |    std                  | 0.935       |
# |    value_loss           | 133         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 30           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0108761825 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.0381       |
# |    learning_rate        | 0.002        |
# |    loss                 | 117          |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00584     |
# |    std                  | 0.964        |
# |    value_loss           | 46.1         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 290        |
# |    iterations           | 31         |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 3968       |
# | train/                  |            |
# |    approx_kl            | 0.01168289 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.336      |
# |    learning_rate        | 0.002      |
# |    loss                 | 17.6       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0107    |
# |    std                  | 0.959      |
# |    value_loss           | 34.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 32          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016792314 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.272      |
# |    learning_rate        | 0.002       |
# |    loss                 | 4.52        |
# |    n_updates            | 124         |
# |    policy_gradient_loss | 0.000828    |
# |    std                  | 0.953       |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 33          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4224        |
# | train/                  |             |
# |    approx_kl            | 0.026898861 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0173      |
# |    learning_rate        | 0.002       |
# |    loss                 | 2.34        |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.000608   |
# |    std                  | 0.956       |
# |    value_loss           | 33.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 291        |
# |    iterations           | 34         |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 4352       |
# | train/                  |            |
# |    approx_kl            | 0.03842263 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | -0.389     |
# |    learning_rate        | 0.002      |
# |    loss                 | 4.54       |
# |    n_updates            | 132        |
# |    policy_gradient_loss | 0.00282    |
# |    std                  | 0.895      |
# |    value_loss           | 28         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 35          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 4480        |
# | train/                  |             |
# |    approx_kl            | 0.014863575 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.423       |
# |    learning_rate        | 0.002       |
# |    loss                 | 20          |
# |    n_updates            | 136         |
# |    policy_gradient_loss | 0.0204      |
# |    std                  | 0.852       |
# |    value_loss           | 18.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 36          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.032215722 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -0.141      |
# |    learning_rate        | 0.002       |
# |    loss                 | 2.6         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.011       |
# |    std                  | 0.823       |
# |    value_loss           | 24.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 37          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 4736        |
# | train/                  |             |
# |    approx_kl            | 0.027497085 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.002       |
# |    loss                 | 17.7        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | 0.00296     |
# |    std                  | 0.827       |
# |    value_loss           | 34.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 291          |
# |    iterations           | 38           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0056694737 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.871       |
# |    learning_rate        | 0.002        |
# |    loss                 | 14.8         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | 0.00364      |
# |    std                  | 0.832        |
# |    value_loss           | 218          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 291        |
# |    iterations           | 39         |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 4992       |
# | train/                  |            |
# |    approx_kl            | 0.03066051 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | -0.882     |
# |    learning_rate        | 0.002      |
# |    loss                 | 2.09       |
# |    n_updates            | 152        |
# |    policy_gradient_loss | 0.00458    |
# |    std                  | 0.815      |
# |    value_loss           | 275        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 40          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.050053947 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -6.42       |
# |    learning_rate        | 0.002       |
# |    loss                 | 20.9        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | 0.00953     |
# |    std                  | 0.814       |
# |    value_loss           | 219         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 41          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 5248        |
# | train/                  |             |
# |    approx_kl            | 0.035684314 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.002       |
# |    loss                 | 4.7         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000959   |
# |    std                  | 0.824       |
# |    value_loss           | 67.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 291        |
# |    iterations           | 42         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 5376       |
# | train/                  |            |
# |    approx_kl            | 0.03617734 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | -0.407     |
# |    learning_rate        | 0.002      |
# |    loss                 | 7.8        |
# |    n_updates            | 164        |
# |    policy_gradient_loss | -0.00782   |
# |    std                  | 0.83       |
# |    value_loss           | 90.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 43          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 5504        |
# | train/                  |             |
# |    approx_kl            | 0.022873526 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0435      |
# |    learning_rate        | 0.002       |
# |    loss                 | 3.49        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.824       |
# |    value_loss           | 13.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 291        |
# |    iterations           | 44         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 5632       |
# | train/                  |            |
# |    approx_kl            | 0.02455042 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.21      |
# |    explained_variance   | 0.522      |
# |    learning_rate        | 0.002      |
# |    loss                 | 4.79       |
# |    n_updates            | 172        |
# |    policy_gradient_loss | -0.012     |
# |    std                  | 0.796      |
# |    value_loss           | 22         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 45          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 5760        |
# | train/                  |             |
# |    approx_kl            | 0.015944317 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | -0.375      |
# |    learning_rate        | 0.002       |
# |    loss                 | 48.5        |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.00374    |
# |    std                  | 0.785       |
# |    value_loss           | 51          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 291        |
# |    iterations           | 46         |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 5888       |
# | train/                  |            |
# |    approx_kl            | 0.10894291 |
# |    clip_fraction        | 0.326      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.251      |
# |    learning_rate        | 0.002      |
# |    loss                 | 14.3       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.0107     |
# |    std                  | 0.76       |
# |    value_loss           | 16         |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 291       |
# |    iterations           | 47        |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 6016      |
# | train/                  |           |
# |    approx_kl            | 0.0253333 |
# |    clip_fraction        | 0.207     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.14     |
# |    explained_variance   | -0.411    |
# |    learning_rate        | 0.002     |
# |    loss                 | 194       |
# |    n_updates            | 184       |
# |    policy_gradient_loss | 0.0122    |
# |    std                  | 0.757     |
# |    value_loss           | 211       |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 291        |
# |    iterations           | 48         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.06973168 |
# |    clip_fraction        | 0.324      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.0413     |
# |    learning_rate        | 0.002      |
# |    loss                 | 2.21       |
# |    n_updates            | 188        |
# |    policy_gradient_loss | -0.00469   |
# |    std                  | 0.753      |
# |    value_loss           | 37.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 291        |
# |    iterations           | 49         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 6272       |
# | train/                  |            |
# |    approx_kl            | 0.04917196 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.442      |
# |    learning_rate        | 0.002      |
# |    loss                 | 8.68       |
# |    n_updates            | 192        |
# |    policy_gradient_loss | -0.0031    |
# |    std                  | 0.757      |
# |    value_loss           | 88.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 50          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.061556526 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.002       |
# |    loss                 | 4.67        |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.00258    |
# |    std                  | 0.773       |
# |    value_loss           | 19.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 51         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 6528       |
# | train/                  |            |
# |    approx_kl            | 0.09459311 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.002      |
# |    loss                 | 16.9       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | 0.00984    |
# |    std                  | 0.731      |
# |    value_loss           | 8.36       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 52          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.020442829 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.002       |
# |    loss                 | 4.65        |
# |    n_updates            | 204         |
# |    policy_gradient_loss | 0.00998     |
# |    std                  | 0.717       |
# |    value_loss           | 17.9        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 292       |
# |    iterations           | 53        |
# |    time_elapsed         | 23        |
# |    total_timesteps      | 6784      |
# | train/                  |           |
# |    approx_kl            | 0.0298451 |
# |    clip_fraction        | 0.24      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | -0.0621   |
# |    learning_rate        | 0.002     |
# |    loss                 | 4.27      |
# |    n_updates            | 208       |
# |    policy_gradient_loss | 0.00772   |
# |    std                  | 0.746     |
# |    value_loss           | 16.9      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 54          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 6912        |
# | train/                  |             |
# |    approx_kl            | 0.041360848 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.00106     |
# |    learning_rate        | 0.002       |
# |    loss                 | 14.4        |
# |    n_updates            | 212         |
# |    policy_gradient_loss | 0.0166      |
# |    std                  | 0.754       |
# |    value_loss           | 43.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 55         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 7040       |
# | train/                  |            |
# |    approx_kl            | 0.11543834 |
# |    clip_fraction        | 0.404      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | -0.225     |
# |    learning_rate        | 0.002      |
# |    loss                 | 17         |
# |    n_updates            | 216        |
# |    policy_gradient_loss | 0.0727     |
# |    std                  | 0.718      |
# |    value_loss           | 80.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 56          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.054601252 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.309       |
# |    learning_rate        | 0.002       |
# |    loss                 | 4.67        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0263      |
# |    std                  | 0.772       |
# |    value_loss           | 47.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 57         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 7296       |
# | train/                  |            |
# |    approx_kl            | 0.14115904 |
# |    clip_fraction        | 0.387      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.002      |
# |    loss                 | 32.9       |
# |    n_updates            | 224        |
# |    policy_gradient_loss | 0.0657     |
# |    std                  | 0.782      |
# |    value_loss           | 32.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 58         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 7424       |
# | train/                  |            |
# |    approx_kl            | 0.07395966 |
# |    clip_fraction        | 0.412      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.002      |
# |    loss                 | 1.41       |
# |    n_updates            | 228        |
# |    policy_gradient_loss | 0.0141     |
# |    std                  | 0.897      |
# |    value_loss           | 7.89       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 59          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 7552        |
# | train/                  |             |
# |    approx_kl            | 0.039335664 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.002       |
# |    loss                 | 1.92        |
# |    n_updates            | 232         |
# |    policy_gradient_loss | 0.0316      |
# |    std                  | 0.933       |
# |    value_loss           | 4.68        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 60         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 7680       |
# | train/                  |            |
# |    approx_kl            | 0.10279545 |
# |    clip_fraction        | 0.322      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.002      |
# |    loss                 | 2.01       |
# |    n_updates            | 236        |
# |    policy_gradient_loss | 0.0302     |
# |    std                  | 0.901      |
# |    value_loss           | 2.22       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 61          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 7808        |
# | train/                  |             |
# |    approx_kl            | 0.020982506 |
# |    clip_fraction        | 0.344       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 30.8        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0278      |
# |    std                  | 0.894       |
# |    value_loss           | 291         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 62          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 7936        |
# | train/                  |             |
# |    approx_kl            | 0.011791281 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00429    |
# |    learning_rate        | 0.002       |
# |    loss                 | 115         |
# |    n_updates            | 244         |
# |    policy_gradient_loss | 0.00668     |
# |    std                  | 0.881       |
# |    value_loss           | 275         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 63          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 8064        |
# | train/                  |             |
# |    approx_kl            | 0.040295623 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.002       |
# |    loss                 | 3.16        |
# |    n_updates            | 248         |
# |    policy_gradient_loss | -0.0183     |
# |    std                  | 0.894       |
# |    value_loss           | 11.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 64          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.022961643 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.002       |
# |    loss                 | 8.88        |
# |    n_updates            | 252         |
# |    policy_gradient_loss | 0.0293      |
# |    std                  | 0.851       |
# |    value_loss           | 14          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 65          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 8320        |
# | train/                  |             |
# |    approx_kl            | 0.053467594 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.002       |
# |    loss                 | 451         |
# |    n_updates            | 256         |
# |    policy_gradient_loss | 0.0324      |
# |    std                  | 0.86        |
# |    value_loss           | 328         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 66           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 8448         |
# | train/                  |              |
# |    approx_kl            | 0.0100832805 |
# |    clip_fraction        | 0.229        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -2.22e-05    |
# |    learning_rate        | 0.002        |
# |    loss                 | 9.41         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00193     |
# |    std                  | 0.853        |
# |    value_loss           | 4.92         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 67           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 8576         |
# | train/                  |              |
# |    approx_kl            | 0.0028025769 |
# |    clip_fraction        | 0.277        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.002        |
# |    loss                 | 153          |
# |    n_updates            | 264          |
# |    policy_gradient_loss | 0.0257       |
# |    std                  | 0.824        |
# |    value_loss           | 127          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 68          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.068108216 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.033      |
# |    learning_rate        | 0.002       |
# |    loss                 | 495         |
# |    n_updates            | 268         |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 0.826       |
# |    value_loss           | 526         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 69         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 8832       |
# | train/                  |            |
# |    approx_kl            | 0.04243166 |
# |    clip_fraction        | 0.199      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | -0.787     |
# |    learning_rate        | 0.002      |
# |    loss                 | 14.5       |
# |    n_updates            | 272        |
# |    policy_gradient_loss | 0.00812    |
# |    std                  | 0.864      |
# |    value_loss           | 24.3       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 70          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.009324526 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.0618      |
# |    learning_rate        | 0.002       |
# |    loss                 | 869         |
# |    n_updates            | 276         |
# |    policy_gradient_loss | 0.0017      |
# |    std                  | 0.859       |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 71          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 9088        |
# | train/                  |             |
# |    approx_kl            | 0.008780273 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.0733      |
# |    learning_rate        | 0.002       |
# |    loss                 | 41.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00983    |
# |    std                  | 0.827       |
# |    value_loss           | 68.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 72         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.02079235 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.00168    |
# |    learning_rate        | 0.002      |
# |    loss                 | 49.6       |
# |    n_updates            | 284        |
# |    policy_gradient_loss | 0.0098     |
# |    std                  | 0.831      |
# |    value_loss           | 103        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 73         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 9344       |
# | train/                  |            |
# |    approx_kl            | 0.00783287 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.231      |
# |    learning_rate        | 0.002      |
# |    loss                 | 3.54       |
# |    n_updates            | 288        |
# |    policy_gradient_loss | 0.00692    |
# |    std                  | 0.828      |
# |    value_loss           | 67.3       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 292       |
# |    iterations           | 74        |
# |    time_elapsed         | 32        |
# |    total_timesteps      | 9472      |
# | train/                  |           |
# |    approx_kl            | 0.0078776 |
# |    clip_fraction        | 0.0566    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.23     |
# |    explained_variance   | -0.476    |
# |    learning_rate        | 0.002     |
# |    loss                 | 33.1      |
# |    n_updates            | 292       |
# |    policy_gradient_loss | -0.00012  |
# |    std                  | 0.823     |
# |    value_loss           | 31.6      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 75          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 9600        |
# | train/                  |             |
# |    approx_kl            | 0.013412895 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.194      |
# |    learning_rate        | 0.002       |
# |    loss                 | 14.1        |
# |    n_updates            | 296         |
# |    policy_gradient_loss | -0.00644    |
# |    std                  | 0.827       |
# |    value_loss           | 27.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 76           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 9728         |
# | train/                  |              |
# |    approx_kl            | 0.0073891487 |
# |    clip_fraction        | 0.0762       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.318       |
# |    learning_rate        | 0.002        |
# |    loss                 | 5.54         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.00219      |
# |    std                  | 0.818        |
# |    value_loss           | 40.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 77          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 9856        |
# | train/                  |             |
# |    approx_kl            | 0.010188688 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.002       |
# |    loss                 | 10.3        |
# |    n_updates            | 304         |
# |    policy_gradient_loss | 0.0048      |
# |    std                  | 0.824       |
# |    value_loss           | 9.29        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 78          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.080087796 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.545      |
# |    learning_rate        | 0.002       |
# |    loss                 | 26          |
# |    n_updates            | 308         |
# |    policy_gradient_loss | 0.0218      |
# |    std                  | 0.805       |
# |    value_loss           | 19.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | -3.34e+04  |
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 79         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 10112      |
# | train/                  |            |
# |    approx_kl            | 0.01711044 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.19      |
# |    explained_variance   | 0.506      |
# |    learning_rate        | 0.002      |
# |    loss                 | 4.76       |
# |    n_updates            | 312        |
# |    policy_gradient_loss | 0.000251   |
# |    std                  | 0.792      |
# |    value_loss           | 13.8       |
# ----------------------------------------
