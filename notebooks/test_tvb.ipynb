# %%
from TVB.tvb_wrapper import TVBWrapper
env = TVBWrapper()
# Out:
# 2024-10-29 15:43:35,183 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-10-29 15:43:35,250 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)

# %%
env.reset()
for i in range(1000):
    action = env.action_space.sample()
    state, reward, _, done, _ = env.step(action)
    if done:
        break
# Out:
# 2024-10-29 15:43:36,840 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:48,901 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:49,035 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:49,122 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:49,207 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:49,311 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:49,398 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:49,484 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:49,590 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:49,677 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:49,767 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:49,871 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:49,958 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:50,044 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:50,148 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:50,235 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:50,321 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:50,429 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:50,517 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:50,603 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:50,707 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:50,796 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:50,882 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:51,028 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:51,115 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:51,200 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:51,302 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:51,390 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:51,480 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:51,584 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:51,669 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:51,756 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:51,860 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:51,947 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:52,033 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:52,136 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:52,223 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:52,308 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:52,411 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:52,501 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:52,586 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:52,689 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:52,780 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:52,866 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:52,971 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:53,058 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:53,198 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:53,300 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:53,386 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:53,470 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:53,578 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:53,665 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:53,751 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:53,854 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:53,943 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:54,031 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:54,137 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:54,224 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:54,312 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:54,417 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:54,507 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:54,597 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:54,703 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:54,793 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:54,879 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:54,985 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:55,070 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:55,156 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:55,288 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:55,375 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:55,464 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:55,566 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:55,656 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:55,741 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:55,845 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:55,932 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:56,018 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:56,122 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:56,209 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:56,294 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:56,398 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:56,484 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:56,570 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:56,674 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:56,763 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:56,849 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:56,953 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:57,040 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:57,127 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:57,231 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:57,322 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:57,412 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:57,516 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:57,601 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:57,687 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:57,804 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:57,890 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:57,976 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:58,080 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:58,167 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:58,255 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:58,360 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:58,446 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:58,532 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:58,636 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:58,723 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:58,813 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:58,917 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:59,004 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:59,089 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:59,193 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:59,279 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:59,366 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:59,475 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:59,561 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:59,650 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:59,754 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:59,843 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:43:59,932 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:00,037 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:00,124 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:00,209 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:00,312 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:00,400 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:00,488 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:00,592 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:00,678 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:00,764 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:00,868 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:00,956 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:01,045 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:01,148 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:01,234 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:01,320 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:01,424 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:01,511 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:01,630 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:01,734 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:01,821 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:01,908 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:02,018 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:02,105 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:02,190 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:02,296 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:02,384 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:02,471 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:02,577 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:02,664 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:02,752 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:02,858 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:02,945 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:03,034 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:03,139 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:03,224 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:03,318 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:03,421 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:03,511 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:03,601 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:03,706 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:03,796 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:03,883 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:03,988 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:04,077 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:04,167 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:04,271 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:04,359 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# 2024-10-29 15:44:04,446 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_154/17968698.py in <module>
#       2 for i in range(1000):
#       3     action = env.action_space.sample()
# ----> 4     state, reward, _, done, _ = env.step(action)
#       5     if done:
#       6         break
#
# /home/rl_course/TVB/tvb_wrapper.py in step(self, action)
#     113         #TODO: stimulus from action
#     114         self.simulator.configure()
# --> 115         (traw, raw), (tEEG, EEG) = self.simulator.run(simulation_length=self.timestep)
#     116         raw_nstep = raw.shape[0]
#     117         # update raw history buffer
#
# /usr/local/lib/python3.7/dist-packages/tvb/simulator/simulator.py in run(self, **kwds)
#     625             xs.append([])
#     626         wall_time_start = time.time()
# --> 627         for data in self(**kwds):
#     628             for tl, xl, t_x in zip(ts, xs, data):
#     629                 if t_x is not None:
#
# /usr/local/lib/python3.7/dist-packages/tvb/simulator/simulator.py in __call__(self, simulation_length, random_state, n_steps)
#     358             state = self.integrate_next_step(state, self.model, node_coupling, local_coupling, stimulus)
#     359             self._loop_update_history(step, state)
# --> 360             node_coupling = self._loop_compute_node_coupling(step + 1)
#     361             output = self._loop_monitor_output(step, state, node_coupling)
#     362             if output is not None:
#
# /usr/local/lib/python3.7/dist-packages/tvb/simulator/simulator.py in _loop_compute_node_coupling(self, step)
#     283     def _loop_compute_node_coupling(self, step):
#     284         """Compute delayed node coupling values."""
# --> 285         coupling = self.coupling(step, self.history)
#     286         if self.surface is not None:
#     287             coupling = coupling[:, self.surface.region_mapping]
#
# /usr/local/lib/python3.7/dist-packages/tvb/simulator/coupling.py in __call__(self, step, history)
#     164         weights_col = h.nnz_weights.reshape((h.n_nnzw, 1))
#     165         lri, nzr = self._lri(h.nnz_row_el_idx)
# --> 166         sum[:, nzr] = numpy.add.reduceat(weights_col * pre, lri, axis=1)
#     167         return self.post(sum)
#     168
#
# KeyboardInterrupt:

# %% [markdown]
# Debugging the wrapper.

# %%
from tvb.simulator.lab import *
import numpy as np

# %%
# %matplotlib inline

# %%
timestep=10
history_len=200
max_len=6000
dt=0.05
model = models.Epileptor()
model.variables_of_interest = ('x1', 'y1', 'z', 'x2', 'y2', 'g')
model.x0 = np.ones((76))*-2.4
model.x0[[62,47,40]] = np.ones((3))*-1.6
# 69: rTCL, 72: rTCV, minor epileptogenic regions
model.x0[[69,72]] = np.ones((2))*-1.8
# in one single tutorial it is connectiity.Connectivity(load_default=True), in others it is connectivity.Connectivity.from_file(). Ehhhhhhh
conn = connectivity.Connectivity.from_file()
# what does difference coupling functions mean?
# https://github.com/the-virtual-brain/tvb-library/blob/trunk/tvb/simulator/coupling.py
coupl = coupling.Difference(a=np.array([1.]))
hiss = noise.Additive(nsig=np.array([0., 0., 0., 0.0003, 0.0003, 0.]))
integrator = integrators.HeunStochastic(dt=dt, noise=hiss)
dt = dt  # the dt for integrator, unit is ms
# load the default region mapping
rm = region_mapping.RegionMapping.from_file()

# Initialise EEG Monitor with period in physical time
mon_raw = monitors.Raw()
mon_EEG = monitors.EEG.from_file()
EEG_labels = mon_EEG.sensors.labels  # channel names
mon_EEG.region_mapping=rm
mon_EEG.period=1. 

# Bundle them
what_to_watch = (mon_raw, mon_EEG)

sim = simulator.Simulator(model=model, connectivity=conn,
                        coupling=coupl, 
                        integrator=integrator, monitors=what_to_watch)
sim.configure()
init_length = max(4000,timestep*history_len*2)
# Out:
# 2024-10-29 14:29:10,046 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-10-29 14:29:10,114 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)

# %%
(traw, raw), (tEEG, EEG) = sim.run(simulation_length=init_length)
EEG = EEG[:,3,:,0] - EEG[:,0,:,0]
EEG /= (np.max(EEG,0) - np.min(EEG,0))
EEG -= np.mean(EEG,0)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.plot(tEEG,5*EEG + np.r_[:len(EEG_labels)])
plt.yticks(np.r_[:65], mon_EEG.sensors.labels)
plt.title("EEG")
# Out:
# Text(0.5, 1.0, 'EEG')

# %%
eqn_t = equations.Linear()
eqn_t.parameters["a"] = 0.00
eqn_t.parameters["b"] = 10
weighting = np.zeros((76))
weighting[[69, 72]] = np.array([2.])
stimulus = patterns.StimuliRegion(temporal = eqn_t,
                                  connectivity = conn, 
                                  weight = weighting)
stimulus.configure_space()

# %%
sim = simulator.Simulator(model=model, connectivity=conn,
                        coupling=coupl, 
                        integrator=integrator, monitors=what_to_watch,
                        initial_conditions=raw, stimulus=stimulus)
sim.configure()
(traw, raw), (tEEG, EEG) = sim.run(simulation_length=timestep)
# Out:
# 2024-10-29 14:31:44,140 - ERROR - tvb.simulator.simulator - Bad Simulator.integrator.noise.nsig shape: (6, 1, 1)
